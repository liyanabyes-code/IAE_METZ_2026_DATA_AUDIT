# %%
print ("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Let's go learning PYTHON !
# # Ceci est un commentaire dans la cellule de code
# # Python est de la programmation OBJET. on definie des variables.
# name = "Liyana"

# %%
pi = 3.14159
print(pi)
# Out:
# 3.14159

# %%
# Mais nous sommes humains, donc nous LISONS des PHRASES.
# Des lors, on utilise la fonction PRINT F, qui permet d'avoir un print proche de notre language
# Les variables y sont DYNAMIQUES
print(f'Hello, les boloss dont {name}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 # Mais nous sommes humains, donc nous LISONS des PHRASES.
#       2 # Des lors, on utilise la fonction PRINT F, qui permet d'avoir un print proche de notre language
#       3 # Les variables y sont DYNAMIQUES
# ----> 4 print(f'Hello, les boloss dont {name}')
#
# NameError: name 'name' is not defined

# %%
# Les LISTES se nomment list en anglais
stocks = ["AAPL","GOOGL","MSFT","TSLA"]

# %%
stocks
# Out:
# ['AAPL', 'GOOGL', 'MSFT', 'TSLA']

# %%
# C le fait que PYHTON repose sur des PACKAGES
# Donc on gagne un temps fou a ne pas re inventer la roue a chaque fois
! pip install yfinance
# Out:
# 2834.82s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
#   Using cached yfinance-1.0-py2.py3-none-any.whl.metadata (6.0 kB)
# ...
#   Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# ...
# Using cached yfinance-1.0-py2.py3-none-any.whl (127 kB)
# Using cached curl_cffi-0.13.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [yfinance]]
# ...

# %%
import yfinance as yf
